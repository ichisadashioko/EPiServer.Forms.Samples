# %%
import os
import re

import xml
import xml.etree.ElementTree as ET

# %%
import lxml
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-a1044314e73b> in <module>
# ----> 1 import lxml
#
# ModuleNotFoundError: No module named 'lxml'

# %%
root_langs = './EmbeddedLangFiles'
file_list = os.listdir(root_langs)
for fname in file_list:
    child_path = f'{root_langs}/{fname}'
    xml_tree = ET.parse(child_path)
    break

# %%
root = xml_tree.getroot()
root
# Out:
# <Element 'languages' at 0x000001C966E6F408>

# %%
for e in root.iter():
    print(f'{e.tag}: {repr(e.text)}')
# Out:
# languages: '\n\n  '
# language: '\n\n    '
# groups: '\n      '
# basicelements: 'Basic Elements'
# enums: '\n      '
# episerver: '\n        '
# forms: '\n          '
# samples: '\n            '
# criteria: '\n              '
# submissionstatus: '\n                '
# hassubmitted: 'Has submitted'
# hasnotsubmitted: 'Has not submitted'
# fieldvaluecomparecondition: '\n                '
# equals: 'equals'
# notequals: 'not equal to'
# contains: 'contains'
# notcontains: 'does not contain'
# episerver: '\n      '
# forms: '\n        '
# samples: '\n          '
# criteria: '\n            '
# formcriterion: '\n              '
# category: 'Episerver Forms'
# displayname: 'Submitted Form'
# description: 'Checks for form submission by the visitor.'
# submissionstatus: 'Submission status'
# selectedform: 'Selected form'
# submittedvaluecriterion: '\n              '
# category: 'Episerver Forms'
# displayname: 'Submitted Form Value'
# description: 'Checks for form submission value by the visitor.'
# selectedform: 'Selected form'
# selectedfield: 'Selected field'
# condition: 'Condition'
# value: 'Value'
# datetimepickertype: '\n            '
# datepicker: 'Date picker'
# timepicker: 'Time picker'
# datetimepicker: 'Date time picker'
# confirmationdialog: '\n            '
# title: 'Summary'
# buttons: '\n              '
# ok: 'OK'
# cancel: 'Cancel'
# editview: '\n            '
# requirejs: 'JavaScript is required to display reCAPTCHA.'
# messages: '\n            '
# imagesubmitbutton: '\n              '
# initializationmessage: 'This is an image submit button. Please, choose an image for it.'
# viewmode: '\n          '
# addresselement: '\n            '
# addresslabel: 'Adresse'
# streetlabel: 'Gade'
# citylabel: 'By'
# statelabel: 'Region'
# postallabel: 'Postnummer'
# countrylabel: 'Land'
# validators: '\n          '
# episerver.forms.samples.implementation.validation.datetimevalidator: '\n            '
# displayname: 'Datetime validator'
# message: 'Enter a valid date time in {0} hh:mm format.'
# episerver.forms.samples.implementation.validation.datevalidator: '\n            '
# displayname: 'Date validator'
# message: 'Enter a valid date in {0} format.'
# episerver.forms.samples.implementation.validation.timevalidator: '\n            '
# displayname: 'Time validator'
# message: 'Enter a valid time, e.g. 10:20 AM.'
# episerver.forms.samples.implementation.validation.recaptchavalidator: '\n            '
# displayname: 'Recaptcha validator'
# message: 'Invalid captcha value.'
# episerver.forms.implementation.validation.datetimerangevalidator: '\n            '
# displayname: 'Dato-/tidsinterval'
# message: 'Angiv et gyldigt dato-/tidsinterval.'
# episerver.forms.implementation.validation.addressvalidator: '\n            '
# displayname: 'Adresse'
# message: 'Angiv en gyldig adresse.'
# contenttypes: '\n      '
# datetimeelementblock: '\n        '
# name: 'Date time'
# description: None
# newitemdefaultname: 'New date time'
# properties: '\n\n          '
# description: '\n            '
# caption: 'Tooltip'
# help: 'Displays as a tooltip or help text of an element.'
# pickertype: '\n            '
# caption: 'Picker type'
# help: 'Select picker type for the property.'
# recaptchaelementblock: '\n        '
# name: 'reCAPTCHA'
# description: None
# newitemdefaultname: 'New reCAPTCHA'
# properties: '\n          '
# sitekey: '\n            '
# caption: 'Site key'
# help: 'Enter site key for reCAPTCHA.'
# secretkey: '\n            '
# caption: 'Secret key'
# help: 'The shared key between your site and reCAPTCHA.'
# datetimerangeelementblock: '\n        '
# name: 'Dato-/tidsinterval'
# description: None
# newitemdefaultname: 'Nyt dato-/tidsinterval'
# properties: '\n\n          '
# description: '\n            '
# caption: 'Værktøjstip'
# help: 'Vises som et værktøjstip eller en hjælpetekst til et element.'
# pickertype: '\n            '
# caption: 'Vælgertype'
# help: 'Vælg vælgertype for egenskaben.'
# addresseselementblock: '\n        '
# name: 'Adresse'
# description: None
# newitemdefaultname: 'Ny adresse'
# properties: '\n\n          '
# description: '\n            '
# caption: 'Værktøjstip'
# help: 'Vises som et værktøjstip eller en hjælpetekst til et element.'
# mapwidth: '\n            '
# caption: 'Kortbredde'
# help: 'Bredden af det kort, der er knyttet til elementet.'
# mapheight: '\n            '
# caption: 'Korthøjde'
# help: 'Højden af det kort, der er knyttet til elementet.'
# addresslabel: '\n            '
# caption: 'Detaljeret adresse'
# help: None
# streetlabel: '\n            '
# caption: 'Gadenavn'
# help: None
# citylabel: '\n            '
# caption: 'Bynavn'
# help: None
# statelabel: '\n            '
# caption: 'Regionsnavn'
# help: None
# postalLabel: '\n            '
# caption: 'Postnummerværdi'
# help: None
# countrylabel: '\n            '
# caption: 'Landenavn'
# help: None

# %%
root[0][0]
# Out:
# <Element 'groups' at 0x000001C966E6F4A8>

# %%
root.attrib
# Out:
# {}

# %%
class XMLElement:
    def __init__(self, tag, text, attrib, path):
        self.tag = tag
        self.text = text
        self.attrib = attrib
        self.path = path
    
    def __repr__(self):
        return f'''{self.path}
  tag: {self.tag}
  text: {repr(self.text)}
  attrib: {self.attrib}'''
#         return f'{self.path}, {self.tag}, {self.text}'

# %%
def list_tree(e: xml.etree.ElementTree.Element, parent=None):
    e_list = []
    
    if parent is not None:
        e_path = f'{parent}/{e.tag}'
    else:
        e_path = e.tag
    
    xml_element = XMLElement(
        tag=e.tag,
        text=e.text,
        attrib=e.attrib,
        path=e_path,
    )

    if e.text is not None:
        if not e.text.isspace():
            e_list.append(xml_element)
    
    for child in e:
        e_list.extend(list_tree(child, parent=e_path))

    return e_list

# %%
e_list = list_tree(root)

# %%
e_list.sort(key=lambda x: x.path)

# %%
for e in e_list:
    print(e)
# Out:
# languages/language/contenttypes/addresseselementblock/name
#   tag: name
#   text: 'Adresse'
#   attrib: {}
# languages/language/contenttypes/addresseselementblock/newitemdefaultname
#   tag: newitemdefaultname
#   text: 'Ny adresse'
#   attrib: {}
# languages/language/contenttypes/addresseselementblock/properties/addresslabel/caption
#   tag: caption
#   text: 'Detaljeret adresse'
#   attrib: {}
# languages/language/contenttypes/addresseselementblock/properties/citylabel/caption
#   tag: caption
#   text: 'Bynavn'
#   attrib: {}
# languages/language/contenttypes/addresseselementblock/properties/countrylabel/caption
#   tag: caption
#   text: 'Landenavn'
#   attrib: {}
# languages/language/contenttypes/addresseselementblock/properties/description/caption
#   tag: caption
#   text: 'Værktøjstip'
#   attrib: {}
# languages/language/contenttypes/addresseselementblock/properties/description/help
#   tag: help
#   text: 'Vises som et værktøjstip eller en hjælpetekst til et element.'
#   attrib: {}
# languages/language/contenttypes/addresseselementblock/properties/mapheight/caption
#   tag: caption
#   text: 'Korthøjde'
#   attrib: {}
# languages/language/contenttypes/addresseselementblock/properties/mapheight/help
#   tag: help
#   text: 'Højden af det kort, der er knyttet til elementet.'
#   attrib: {}
# languages/language/contenttypes/addresseselementblock/properties/mapwidth/caption
#   tag: caption
#   text: 'Kortbredde'
#   attrib: {}
# languages/language/contenttypes/addresseselementblock/properties/mapwidth/help
#   tag: help
#   text: 'Bredden af det kort, der er knyttet til elementet.'
#   attrib: {}
# languages/language/contenttypes/addresseselementblock/properties/postalLabel/caption
#   tag: caption
#   text: 'Postnummerværdi'
#   attrib: {}
# languages/language/contenttypes/addresseselementblock/properties/statelabel/caption
#   tag: caption
#   text: 'Regionsnavn'
#   attrib: {}
# languages/language/contenttypes/addresseselementblock/properties/streetlabel/caption
#   tag: caption
#   text: 'Gadenavn'
#   attrib: {}
# languages/language/contenttypes/datetimeelementblock/name
#   tag: name
#   text: 'Date time'
#   attrib: {}
# languages/language/contenttypes/datetimeelementblock/newitemdefaultname
#   tag: newitemdefaultname
#   text: 'New date time'
#   attrib: {}
# languages/language/contenttypes/datetimeelementblock/properties/description/caption
#   tag: caption
#   text: 'Tooltip'
#   attrib: {}
# languages/language/contenttypes/datetimeelementblock/properties/description/help
#   tag: help
#   text: 'Displays as a tooltip or help text of an element.'
#   attrib: {}
# languages/language/contenttypes/datetimeelementblock/properties/pickertype/caption
#   tag: caption
#   text: 'Picker type'
#   attrib: {}
# languages/language/contenttypes/datetimeelementblock/properties/pickertype/help
#   tag: help
#   text: 'Select picker type for the property.'
#   attrib: {}
# languages/language/contenttypes/datetimerangeelementblock/name
#   tag: name
#   text: 'Dato-/tidsinterval'
#   attrib: {}
# languages/language/contenttypes/datetimerangeelementblock/newitemdefaultname
#   tag: newitemdefaultname
#   text: 'Nyt dato-/tidsinterval'
#   attrib: {}
# languages/language/contenttypes/datetimerangeelementblock/properties/description/caption
#   tag: caption
#   text: 'Værktøjstip'
#   attrib: {}
# languages/language/contenttypes/datetimerangeelementblock/properties/description/help
#   tag: help
#   text: 'Vises som et værktøjstip eller en hjælpetekst til et element.'
#   attrib: {}
# languages/language/contenttypes/datetimerangeelementblock/properties/pickertype/caption
#   tag: caption
#   text: 'Vælgertype'
#   attrib: {}
# languages/language/contenttypes/datetimerangeelementblock/properties/pickertype/help
#   tag: help
#   text: 'Vælg vælgertype for egenskaben.'
#   attrib: {}
# languages/language/contenttypes/recaptchaelementblock/name
#   tag: name
#   text: 'reCAPTCHA'
#   attrib: {}
# languages/language/contenttypes/recaptchaelementblock/newitemdefaultname
#   tag: newitemdefaultname
#   text: 'New reCAPTCHA'
#   attrib: {}
# languages/language/contenttypes/recaptchaelementblock/properties/secretkey/caption
#   tag: caption
#   text: 'Secret key'
#   attrib: {}
# languages/language/contenttypes/recaptchaelementblock/properties/secretkey/help
#   tag: help
#   text: 'The shared key between your site and reCAPTCHA.'
#   attrib: {}
# languages/language/contenttypes/recaptchaelementblock/properties/sitekey/caption
#   tag: caption
#   text: 'Site key'
#   attrib: {}
# languages/language/contenttypes/recaptchaelementblock/properties/sitekey/help
#   tag: help
#   text: 'Enter site key for reCAPTCHA.'
#   attrib: {}
# languages/language/enums/episerver/forms/samples/criteria/fieldvaluecomparecondition/contains
#   tag: contains
#   text: 'contains'
#   attrib: {}
# languages/language/enums/episerver/forms/samples/criteria/fieldvaluecomparecondition/equals
#   tag: equals
#   text: 'equals'
#   attrib: {}
# languages/language/enums/episerver/forms/samples/criteria/fieldvaluecomparecondition/notcontains
#   tag: notcontains
#   text: 'does not contain'
#   attrib: {}
# languages/language/enums/episerver/forms/samples/criteria/fieldvaluecomparecondition/notequals
#   tag: notequals
#   text: 'not equal to'
#   attrib: {}
# languages/language/enums/episerver/forms/samples/criteria/submissionstatus/hasnotsubmitted
#   tag: hasnotsubmitted
#   text: 'Has not submitted'
#   attrib: {}
# languages/language/enums/episerver/forms/samples/criteria/submissionstatus/hassubmitted
#   tag: hassubmitted
#   text: 'Has submitted'
#   attrib: {}
# languages/language/episerver/forms/samples/confirmationdialog/buttons/cancel
#   tag: cancel
#   text: 'Cancel'
#   attrib: {}
# languages/language/episerver/forms/samples/confirmationdialog/buttons/ok
#   tag: ok
#   text: 'OK'
#   attrib: {}
# languages/language/episerver/forms/samples/confirmationdialog/title
#   tag: title
#   text: 'Summary'
#   attrib: {}
# languages/language/episerver/forms/samples/criteria/formcriterion/category
#   tag: category
#   text: 'Episerver Forms'
#   attrib: {}
# languages/language/episerver/forms/samples/criteria/formcriterion/description
#   tag: description
#   text: 'Checks for form submission by the visitor.'
#   attrib: {}
# languages/language/episerver/forms/samples/criteria/formcriterion/displayname
#   tag: displayname
#   text: 'Submitted Form'
#   attrib: {}
# languages/language/episerver/forms/samples/criteria/formcriterion/selectedform
#   tag: selectedform
#   text: 'Selected form'
#   attrib: {}
# languages/language/episerver/forms/samples/criteria/formcriterion/submissionstatus
#   tag: submissionstatus
#   text: 'Submission status'
#   attrib: {}
# languages/language/episerver/forms/samples/criteria/submittedvaluecriterion/category
#   tag: category
#   text: 'Episerver Forms'
#   attrib: {}
# languages/language/episerver/forms/samples/criteria/submittedvaluecriterion/condition
#   tag: condition
#   text: 'Condition'
#   attrib: {}
# languages/language/episerver/forms/samples/criteria/submittedvaluecriterion/description
#   tag: description
#   text: 'Checks for form submission value by the visitor.'
#   attrib: {}
# languages/language/episerver/forms/samples/criteria/submittedvaluecriterion/displayname
#   tag: displayname
#   text: 'Submitted Form Value'
#   attrib: {}
# languages/language/episerver/forms/samples/criteria/submittedvaluecriterion/selectedfield
#   tag: selectedfield
#   text: 'Selected field'
#   attrib: {}
# languages/language/episerver/forms/samples/criteria/submittedvaluecriterion/selectedform
#   tag: selectedform
#   text: 'Selected form'
#   attrib: {}
# languages/language/episerver/forms/samples/criteria/submittedvaluecriterion/value
#   tag: value
#   text: 'Value'
#   attrib: {}
# languages/language/episerver/forms/samples/datetimepickertype/datepicker
#   tag: datepicker
#   text: 'Date picker'
#   attrib: {}
# languages/language/episerver/forms/samples/datetimepickertype/datetimepicker
#   tag: datetimepicker
#   text: 'Date time picker'
#   attrib: {}
# languages/language/episerver/forms/samples/datetimepickertype/timepicker
#   tag: timepicker
#   text: 'Time picker'
#   attrib: {}
# languages/language/episerver/forms/samples/editview/requirejs
#   tag: requirejs
#   text: 'JavaScript is required to display reCAPTCHA.'
#   attrib: {}
# languages/language/episerver/forms/samples/messages/imagesubmitbutton/initializationmessage
#   tag: initializationmessage
#   text: 'This is an image submit button. Please, choose an image for it.'
#   attrib: {}
# languages/language/episerver/forms/validators/episerver.forms.implementation.validation.addressvalidator/displayname
#   tag: displayname
#   text: 'Adresse'
#   attrib: {}
# languages/language/episerver/forms/validators/episerver.forms.implementation.validation.addressvalidator/message
#   tag: message
#   text: 'Angiv en gyldig adresse.'
#   attrib: {}
# languages/language/episerver/forms/validators/episerver.forms.implementation.validation.datetimerangevalidator/displayname
#   tag: displayname
#   text: 'Dato-/tidsinterval'
#   attrib: {}
# languages/language/episerver/forms/validators/episerver.forms.implementation.validation.datetimerangevalidator/message
#   tag: message
#   text: 'Angiv et gyldigt dato-/tidsinterval.'
#   attrib: {}
# languages/language/episerver/forms/validators/episerver.forms.samples.implementation.validation.datetimevalidator/displayname
#   tag: displayname
#   text: 'Datetime validator'
#   attrib: {}
# languages/language/episerver/forms/validators/episerver.forms.samples.implementation.validation.datetimevalidator/message
#   tag: message
#   text: 'Enter a valid date time in {0} hh:mm format.'
#   attrib: {}
# languages/language/episerver/forms/validators/episerver.forms.samples.implementation.validation.datevalidator/displayname
#   tag: displayname
#   text: 'Date validator'
#   attrib: {}
# languages/language/episerver/forms/validators/episerver.forms.samples.implementation.validation.datevalidator/message
#   tag: message
#   text: 'Enter a valid date in {0} format.'
#   attrib: {}
# languages/language/episerver/forms/validators/episerver.forms.samples.implementation.validation.recaptchavalidator/displayname
#   tag: displayname
#   text: 'Recaptcha validator'
#   attrib: {}
# languages/language/episerver/forms/validators/episerver.forms.samples.implementation.validation.recaptchavalidator/message
#   tag: message
#   text: 'Invalid captcha value.'
#   attrib: {}
# languages/language/episerver/forms/validators/episerver.forms.samples.implementation.validation.timevalidator/displayname
#   tag: displayname
#   text: 'Time validator'
#   attrib: {}
# languages/language/episerver/forms/validators/episerver.forms.samples.implementation.validation.timevalidator/message
#   tag: message
#   text: 'Enter a valid time, e.g. 10:20 AM.'
#   attrib: {}
# languages/language/episerver/forms/viewmode/addresselement/addresslabel
#   tag: addresslabel
#   text: 'Adresse'
#   attrib: {}
# languages/language/episerver/forms/viewmode/addresselement/citylabel
#   tag: citylabel
#   text: 'By'
#   attrib: {}
# languages/language/episerver/forms/viewmode/addresselement/countrylabel
#   tag: countrylabel
#   text: 'Land'
#   attrib: {}
# languages/language/episerver/forms/viewmode/addresselement/postallabel
#   tag: postallabel
#   text: 'Postnummer'
#   attrib: {}
# languages/language/episerver/forms/viewmode/addresselement/statelabel
#   tag: statelabel
#   text: 'Region'
#   attrib: {}
# languages/language/episerver/forms/viewmode/addresselement/streetlabel
#   tag: streetlabel
#   text: 'Gade'
#   attrib: {}
# languages/language/groups/basicelements
#   tag: basicelements
#   text: 'Basic Elements'
#   attrib: {}

# %%
root

# %%
x = '\n              '

# %%
x.isspace()
# Out:
# True
